# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
crime = pd.read_csv("E:/DataScience/Assignments/Clustering/crime_data.csv")

# %%
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return(x)

# %%
df_crime = norm_func(crime.iloc[:,1:])

# %%
dendrogram = sch.dendrogram(sch.linkage(df_crime, method='single'))

# %%
dendrogram1 = sch.dendrogram(sch.linkage(df_crime, method='complete'))

# %%
dendrogram2 = sch.dendrogram(sch.linkage(df_crime, method='centroid'))

# %%
dendrogram3 = sch.dendrogram(sch.linkage(df_crime, method='average'))

# %%
c = AgglomerativeClustering(n_clusters=4, affinity= 'euclidean', linkage= 'complete')

# %%
mc = AgglomerativeClustering(n_clusters=4, affinity= 'euclidean', linkage= 'complete')

# %%
c1 = AgglomerativeClustering(n_clusters=4, affinity= 'euclidean', linkage= 'single')

# %%
mc1 = AgglomerativeClustering(n_clusters=4, affinity= 'manhattan', linkage= 'single')

# %%
c2 = AgglomerativeClustering(n_clusters=4, affinity= 'euclidean', linkage= 'ward')

# %%
mc2 = AgglomerativeClustering(n_clusters=4, affinity= 'manhattan', linkage= 'ward')

# %%
c3 = AgglomerativeClustering(n_clusters=4, affinity= 'euclidean', linkage= 'average')

# %%
p_c = c.fit_predict(df_crime)
Clusters = pd.DataFrame(p_c,columns=['Clusters'])

# %%
mp_c = mc.fit_predict(df_crime)
MClusters = pd.DataFrame(mp_c,columns=['Clusters'])

# %%
pc = c1.fit_predict(df_crime)
Clusters1 = pd.DataFrame(pc,columns=['Clusters'])

# %%
mpc = mc1.fit_predict(df_crime)
MClusters = pd.DataFrame(mpc,columns=['Clusters'])

# %%
pc1 = c2.fit_predict(df_crime)
Clusters2 = pd.DataFrame(pc1,columns=['Clusters'])

# %%
mpc1 = mc3.fit_predict(df_crime)
MClusters2 = pd.DataFrame(mpc1,columns=['Clusters'])

# %%
pc2 = c3.fit_predict(df_crime)
Clusters3 = pd.DataFrame(pc2,columns=['Clusters'])

# %%
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape
# 0   0.746988  0.654110  0.440678  0.359173
# 1   0.554217  0.746575  0.271186  0.961240
# 2   0.439759  0.852740  0.813559  0.612403
# 3   0.481928  0.496575  0.305085  0.315245
# 4   0.493976  0.791096  1.000000  0.860465
# 5   0.427711  0.544521  0.779661  0.811370
# 6   0.150602  0.222603  0.762712  0.098191
# 7   0.307229  0.660959  0.677966  0.219638
# 8   0.879518  0.993151  0.813559  0.635659
# 9   1.000000  0.568493  0.474576  0.478036
# 10  0.271084  0.003425  0.864407  0.333333
# 11  0.108434  0.256849  0.372881  0.178295
# 12  0.578313  0.698630  0.864407  0.431525
# 13  0.385542  0.232877  0.559322  0.354005
# 14  0.084337  0.037671  0.423729  0.103359
# 15  0.313253  0.239726  0.576271  0.276486
# 16  0.536145  0.219178  0.338983  0.232558
# 17  0.879518  0.698630  0.576271  0.385013
# 18  0.078313  0.130137  0.322034  0.012920
# 19  0.632530  0.873288  0.593220  0.529716
# 20  0.216867  0.356164  0.898305  0.232558
# ...

# %%
df_crime['c_clusterid'] = pd.Series(p_c)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid
# 0   0.746988  0.654110  0.440678  0.359173            0
# 1   0.554217  0.746575  0.271186  0.961240            0
# 2   0.439759  0.852740  0.813559  0.612403            3
# 3   0.481928  0.496575  0.305085  0.315245            1
# 4   0.493976  0.791096  1.000000  0.860465            3
# 5   0.427711  0.544521  0.779661  0.811370            3
# 6   0.150602  0.222603  0.762712  0.098191            1
# 7   0.307229  0.660959  0.677966  0.219638            1
# 8   0.879518  0.993151  0.813559  0.635659            3
# 9   1.000000  0.568493  0.474576  0.478036            0
# 10  0.271084  0.003425  0.864407  0.333333            1
# 11  0.108434  0.256849  0.372881  0.178295            2
# 12  0.578313  0.698630  0.864407  0.431525            3
# 13  0.385542  0.232877  0.559322  0.354005            1
# 14  0.084337  0.037671  0.423729  0.103359            2
# 15  0.313253  0.239726  0.576271  0.276486            1
# ...

# %%
df_crime['clusterid'] = pd.Series(pc)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid
# 0   0.746988  0.654110  0.440678  0.359173            0          0
# 1   0.554217  0.746575  0.271186  0.961240            0          3
# 2   0.439759  0.852740  0.813559  0.612403            3          0
# 3   0.481928  0.496575  0.305085  0.315245            1          0
# 4   0.493976  0.791096  1.000000  0.860465            3          0
# 5   0.427711  0.544521  0.779661  0.811370            3          0
# 6   0.150602  0.222603  0.762712  0.098191            1          0
# 7   0.307229  0.660959  0.677966  0.219638            1          1
# 8   0.879518  0.993151  0.813559  0.635659            3          2
# 9   1.000000  0.568493  0.474576  0.478036            0          0
# 10  0.271084  0.003425  0.864407  0.333333            1          0
# 11  0.108434  0.256849  0.372881  0.178295            2          0
# 12  0.578313  0.698630  0.864407  0.431525            3          0
# ...

# %%
df_crime['clusterid1'] = pd.Series(pc1)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid  clusterid1
# 0   0.746988  0.654110  0.440678  0.359173            0          0           3
# 1   0.554217  0.746575  0.271186  0.961240            0          3           1
# 2   0.439759  0.852740  0.813559  0.612403            3          0           1
# 3   0.481928  0.496575  0.305085  0.315245            1          0           0
# 4   0.493976  0.791096  1.000000  0.860465            3          0           1
# 5   0.427711  0.544521  0.779661  0.811370            3          0           1
# 6   0.150602  0.222603  0.762712  0.098191            1          0           0
# 7   0.307229  0.660959  0.677966  0.219638            1          1           0
# 8   0.879518  0.993151  0.813559  0.635659            3          2           1
# 9   1.000000  0.568493  0.474576  0.478036            0          0           3
# 10  0.271084  0.003425  0.864407  0.333333            1          0           0
# ...

# %%
df_crime['clusterid2'] = pd.Series(pc2)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid  \
# 0   0.746988  0.654110  0.440678  0.359173            0          0
# 1   0.554217  0.746575  0.271186  0.961240            0          3
# 2   0.439759  0.852740  0.813559  0.612403            3          0
# 3   0.481928  0.496575  0.305085  0.315245            1          0
# 4   0.493976  0.791096  1.000000  0.860465            3          0
# 5   0.427711  0.544521  0.779661  0.811370            3          0
# 6   0.150602  0.222603  0.762712  0.098191            1          0
# 7   0.307229  0.660959  0.677966  0.219638            1          1
# 8   0.879518  0.993151  0.813559  0.635659            3          2
# 9   1.000000  0.568493  0.474576  0.478036            0          0
# 10  0.271084  0.003425  0.864407  0.333333            1          0
# 11  0.108434  0.256849  0.372881  0.178295            2          0
# 12  0.578313  0.698630  0.864407  0.431525            3          0
# ...

# %%
df_crime['clusterid4'] = pd.Series(mp_c)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid  \
# 0   0.746988  0.654110  0.440678  0.359173            0          0
# 1   0.554217  0.746575  0.271186  0.961240            0          3
# 2   0.439759  0.852740  0.813559  0.612403            3          0
# 3   0.481928  0.496575  0.305085  0.315245            1          0
# 4   0.493976  0.791096  1.000000  0.860465            3          0
# 5   0.427711  0.544521  0.779661  0.811370            3          0
# 6   0.150602  0.222603  0.762712  0.098191            1          0
# 7   0.307229  0.660959  0.677966  0.219638            1          1
# 8   0.879518  0.993151  0.813559  0.635659            3          2
# 9   1.000000  0.568493  0.474576  0.478036            0          0
# 10  0.271084  0.003425  0.864407  0.333333            1          0
# 11  0.108434  0.256849  0.372881  0.178295            2          0
# 12  0.578313  0.698630  0.864407  0.431525            3          0
# ...

# %%
df_crime['clusterid5'] = pd.Series(mpc)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid  \
# 0   0.746988  0.654110  0.440678  0.359173            0          0
# 1   0.554217  0.746575  0.271186  0.961240            0          3
# 2   0.439759  0.852740  0.813559  0.612403            3          0
# 3   0.481928  0.496575  0.305085  0.315245            1          0
# 4   0.493976  0.791096  1.000000  0.860465            3          0
# 5   0.427711  0.544521  0.779661  0.811370            3          0
# 6   0.150602  0.222603  0.762712  0.098191            1          0
# 7   0.307229  0.660959  0.677966  0.219638            1          1
# 8   0.879518  0.993151  0.813559  0.635659            3          2
# 9   1.000000  0.568493  0.474576  0.478036            0          0
# 10  0.271084  0.003425  0.864407  0.333333            1          0
# 11  0.108434  0.256849  0.372881  0.178295            2          0
# 12  0.578313  0.698630  0.864407  0.431525            3          0
# ...

# %%
df_crime['clusterid6'] = pd.Series(mpc1)
df_crime
# Out:
#       Murder   Assault  UrbanPop      Rape  c_clusterid  clusterid  \
# 0   0.746988  0.654110  0.440678  0.359173            0          0
# 1   0.554217  0.746575  0.271186  0.961240            0          3
# 2   0.439759  0.852740  0.813559  0.612403            3          0
# 3   0.481928  0.496575  0.305085  0.315245            1          0
# 4   0.493976  0.791096  1.000000  0.860465            3          0
# 5   0.427711  0.544521  0.779661  0.811370            3          0
# 6   0.150602  0.222603  0.762712  0.098191            1          0
# 7   0.307229  0.660959  0.677966  0.219638            1          1
# 8   0.879518  0.993151  0.813559  0.635659            3          2
# 9   1.000000  0.568493  0.474576  0.478036            0          0
# 10  0.271084  0.003425  0.864407  0.333333            1          0
# 11  0.108434  0.256849  0.372881  0.178295            2          0
# 12  0.578313  0.698630  0.864407  0.431525            3          0
# ...

# %%
crime['c_clusterid'] = pd.Series(p_c)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  c_clusterid
# 0          Alabama    13.2      236        58  21.2            0
# 1           Alaska    10.0      263        48  44.5            0
# 2          Arizona     8.1      294        80  31.0            3
# 3         Arkansas     8.8      190        50  19.5            1
# 4       California     9.0      276        91  40.6            3
# 5         Colorado     7.9      204        78  38.7            3
# 6      Connecticut     3.3      110        77  11.1            1
# 7         Delaware     5.9      238        72  15.8            1
# 8          Florida    15.4      335        80  31.9            3
# 9          Georgia    17.4      211        60  25.8            0
# 10          Hawaii     5.3       46        83  20.2            1
# 11           Idaho     2.6      120        54  14.2            2
# 12        Illinois    10.4      249        83  24.0            3
# ...

# %%
crime['clusterid'] = pd.Series(pc)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid
# 0          Alabama    13.2      236        58  21.2          0
# 1           Alaska    10.0      263        48  44.5          3
# 2          Arizona     8.1      294        80  31.0          0
# 3         Arkansas     8.8      190        50  19.5          0
# 4       California     9.0      276        91  40.6          0
# 5         Colorado     7.9      204        78  38.7          0
# 6      Connecticut     3.3      110        77  11.1          0
# 7         Delaware     5.9      238        72  15.8          1
# 8          Florida    15.4      335        80  31.9          2
# 9          Georgia    17.4      211        60  25.8          0
# 10          Hawaii     5.3       46        83  20.2          0
# 11           Idaho     2.6      120        54  14.2          0
# 12        Illinois    10.4      249        83  24.0          0
# 13         Indiana     7.2      113        65  21.0          0
# ...

# %%
crime['clusterid1'] = pd.Series(pc1)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid  clusterid1
# 0          Alabama    13.2      236        58  21.2          0           3
# 1           Alaska    10.0      263        48  44.5          3           1
# 2          Arizona     8.1      294        80  31.0          0           1
# 3         Arkansas     8.8      190        50  19.5          0           0
# 4       California     9.0      276        91  40.6          0           1
# 5         Colorado     7.9      204        78  38.7          0           1
# 6      Connecticut     3.3      110        77  11.1          0           0
# 7         Delaware     5.9      238        72  15.8          1           0
# 8          Florida    15.4      335        80  31.9          2           1
# 9          Georgia    17.4      211        60  25.8          0           3
# 10          Hawaii     5.3       46        83  20.2          0           0
# ...

# %%
crime['clusterid2'] = pd.Series(pc2)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid  clusterid1  \
# 0          Alabama    13.2      236        58  21.2          0           3
# 1           Alaska    10.0      263        48  44.5          3           1
# 2          Arizona     8.1      294        80  31.0          0           1
# 3         Arkansas     8.8      190        50  19.5          0           0
# 4       California     9.0      276        91  40.6          0           1
# 5         Colorado     7.9      204        78  38.7          0           1
# 6      Connecticut     3.3      110        77  11.1          0           0
# 7         Delaware     5.9      238        72  15.8          1           0
# 8          Florida    15.4      335        80  31.9          2           1
# 9          Georgia    17.4      211        60  25.8          0           3
# 10          Hawaii     5.3       46        83  20.2          0           0
# ...

# %%
crime['clusterid4'] = pd.Series(mp_c)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid  clusterid1  \
# 0          Alabama    13.2      236        58  21.2          0           3
# 1           Alaska    10.0      263        48  44.5          3           1
# 2          Arizona     8.1      294        80  31.0          0           1
# 3         Arkansas     8.8      190        50  19.5          0           0
# 4       California     9.0      276        91  40.6          0           1
# 5         Colorado     7.9      204        78  38.7          0           1
# 6      Connecticut     3.3      110        77  11.1          0           0
# 7         Delaware     5.9      238        72  15.8          1           0
# 8          Florida    15.4      335        80  31.9          2           1
# 9          Georgia    17.4      211        60  25.8          0           3
# 10          Hawaii     5.3       46        83  20.2          0           0
# ...

# %%
crime['clusterid5'] = pd.Series(mpc)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid  clusterid1  \
# 0          Alabama    13.2      236        58  21.2          0           3
# 1           Alaska    10.0      263        48  44.5          3           1
# 2          Arizona     8.1      294        80  31.0          0           1
# 3         Arkansas     8.8      190        50  19.5          0           0
# 4       California     9.0      276        91  40.6          0           1
# 5         Colorado     7.9      204        78  38.7          0           1
# 6      Connecticut     3.3      110        77  11.1          0           0
# 7         Delaware     5.9      238        72  15.8          1           0
# 8          Florida    15.4      335        80  31.9          2           1
# 9          Georgia    17.4      211        60  25.8          0           3
# 10          Hawaii     5.3       46        83  20.2          0           0
# ...

# %%
crime['clusterid6'] = pd.Series(mpc1)
crime
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  clusterid  clusterid1  \
# 0          Alabama    13.2      236        58  21.2          0           3
# 1           Alaska    10.0      263        48  44.5          3           1
# 2          Arizona     8.1      294        80  31.0          0           1
# 3         Arkansas     8.8      190        50  19.5          0           0
# 4       California     9.0      276        91  40.6          0           1
# 5         Colorado     7.9      204        78  38.7          0           1
# 6      Connecticut     3.3      110        77  11.1          0           0
# 7         Delaware     5.9      238        72  15.8          1           0
# 8          Florida    15.4      335        80  31.9          2           1
# 9          Georgia    17.4      211        60  25.8          0           3
# 10          Hawaii     5.3       46        83  20.2          0           0
# ...

# %%
clusters = crime.iloc[:,1:].groupby(crime.c_clusterid).mean()

# %%
clusters
# Out:
#                 Murder     Assault   UrbanPop     Rape  c_clusterid
# c_clusterid
# 0            14.087500  252.750000  53.500000  24.5375          0.0
# 1             5.715000  132.300000  70.800000  18.1000          1.0
# 2             3.180000   78.700000  49.300000  11.6300          2.0
# 3            10.883333  256.916667  78.333333  32.2500          3.0
